# %% [markdown]
# <a href="https://colab.research.google.com/github/andhinisetyakholili/MSIB-Batch-3-Orbit-Future-Academy/blob/main/Self_Learning_Python_5_Real_World_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. pahami program hero.py kemudian buat Class Diagram dari program tersebut.
#
# Class Diagram bisa dibuat menggunakan office, power point, atau tools online seperti Luchidchart.
#
# FYI: hero.py dapat dibuka menggunakan Notepad, Notepad++, atau Visual Studio Code.
#
# 1. Buat sebuah program OOP dengan ketentuan:
#
#
#
# *   berbeda dari contoh program yang ada di materi (ppt dan colab)List item
#
# *   memiliki 1 parent class
# *   memiliki setidaknya 2 child class
#
#
# *   menerapkan konsep dasar OOP (kecuali abstraction)
#
# *   dilengkapi dengan docstring, contoh docstring bisa dilihat dalam program hero.py
# Setelah program selesai, buatlah:
#
# *   setidaknya 2 instance untuk setiap child class
#
# *   Class Diagram-nya
#
# Andhini Setya Kholili_JumaTec
#
# ![image.png](data:image/png;base64,...)

# %%
# parrent class
class rumus:
  """Bantuan Rumus Bangun Ruang:

  NAME
    Rumus Bangun Ruang

  DESCRIPTION
    Rumus Bangun Ruang
    ==================
    kubus dan balok
  
  CLASES
    kubus
    balok

  FUNCTION
    hitung_volume()->int
    volume()->int
    hitung_luas()->int
    luas()->int
  """

  luas = 0
  volume = 0

  def hitung_volume():
    print("menghitung volume bangun datar")

  def volume(self):
    return self.volume

  def hitung_luas():
    print("menghitung luas bangun datar")

  def luas(self):
    return self.luas

class kubus(rumus):
  def ___init___(self, sisi):
    self.sisi = sisi
  
  def hitung_volume(self):
    self.volume = self.sisi * self.sisi * self.sisi

  def hitung_luas(self):
    self.luas = 6 * self.sisi * self.sisi

class balok(rumus):
  def ___init___(self, panjang, lebar, tinggi):
    self.panjang = panjang
    self.tinggi = tinggi
    self.lebar = lebar
  
  def hitung_volume(self):
    self.volume = self.panjang * self.tinggi * self.lebar

  def hitung_luas(self):
    self.luas = 2 * (self.panjang * self.lebar + self.lebar * self.tinggi + self.lebar * self.tinggi)
